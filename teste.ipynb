# %% [markdown]
# <a href="https://colab.research.google.com/github/Xizizzss/collab-test/blob/main/teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
data = [1,2,3,4,5,6]

# %%
array = np.array(data)

# %%
print(type(array))
# Out:
# <class 'numpy.ndarray'>

# %%
print(array)
# Out:
# [1 2 3 4 5 6]
