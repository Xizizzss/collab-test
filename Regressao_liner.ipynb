# %% [markdown]
# <a href="https://colab.research.google.com/github/Xizizzss/collab-test/blob/main/Regressao_liner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import matplotlib.pyplot as plt

num_quartos = np.array([1, 2, 3, 4, 5, 6, 7])
preco_casas = np.array([10000, 20000, 30000, 40000, 50000, 60000, 70000])

coeficiente_angular, intercepto = np.polyfit(num_quartos, preco_casas, 1)

print(f"Coeficiente angular: {coeficiente_angular}")
print(f"intercepto {intercepto}")

y_pred = coeficiente_angular * num_quartos + intercepto
print(y_pred)


plt.scatter(num_quartos, preco_casas, label='Dados Originais')
plt.plot(num_quartos, y_pred, color='red', linewidth=2, label='Linha de Regressão')
plt.xlabel('Número de Quartos (X)')
plt.ylabel('Preço das Casas (Y)')
plt.legend()
plt.title('Regressão Linear Simples')
plt.grid(True)
plt.show()
# Out:
# Coeficiente angular: 9999.999999999998
# intercepto 2.0067900301084383e-11
# [10000. 20000. 30000. 40000. 50000. 60000. 70000.]
